# %%
import numpy as np
import pandas as pd
potincome = pd.read_csv('PotentialIncomeByMonth_Avg.csv', encoding='ISO-8859-1')
metro_median = pd.read_csv('metromedian.csv')

# %%
metro_median.
# Out:
#            \tdate\tmetro\tmedian
# 0     0\t201604\tportland\t115.0
# 1     1\t201603\tportland\t110.0
# 2     2\t201602\tportland\t108.0
# 3     3\t201601\tportland\t106.0
# 4     4\t201512\tportland\t150.0
# 5     5\t201511\tportland\t150.0
# 6     6\t201510\tportland\t150.0
# 7     7\t201704\tportland\t127.0
# 8     8\t201703\tportland\t128.0
# 9     9\t201702\tportland\t125.0
# 10   10\t201701\tportland\t125.0
# 11   11\t201612\tportland\t120.0
# 12   12\t201611\tportland\t120.0
# 13   13\t201609\tportland\t125.0
# 14   14\t201607\tportland\t121.0
# 15   15\t201610\tportland\t120.0
# 16   16\t201608\tportland\t125.0
# 17   17\t201606\tportland\t111.0
# 18   18\t201605\tportland\t110.0
# 19   19\t201705\tportland\t119.0
# 20   20\t201706\tportland\t120.0
# 21   21\t201707\tportland\t116.0
# 22   22\t201804\tportland\t110.0
# 23   23\t201805\tportland\t110.0
# 24   24\t201708\tportland\t120.0
# 25   25\t201709\tportland\t119.0
# 26   26\t201710\tportland\t118.0
# ...
