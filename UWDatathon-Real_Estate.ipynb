# %%
# Import
import pandas as pd
import numpy as np
real_estate = pd.read_csv('real_estate_newer.csv', encoding='ISO-8859-1')

# %%
# Peek
real_estate
# Out:
#        type  zipcode               city state  \
# 0      ZHVI    10025           New York    NY
# 1      ZHVI    60657            Chicago    IL
# 2      ZHVI    10023           New York    NY
# 3      ZHVI    77494               Katy    TX
# 4      ZHVI    60614            Chicago    IL
# 5      ZHVI    79936            El Paso    TX
# 6      ZHVI    77449               Katy    TX
# 7      ZHVI    77084            Houston    TX
# 8      ZHVI    10002           New York    NY
# 9      ZHVI    10467           New York    NY
# 10     ZHVI    60640            Chicago    IL
# 11     ZHVI    94109      San Francisco    CA
# 12     ZHVI    11226           New York    NY
# 13     ZHVI    10016           New York    NY
# 14     ZHVI    37013          Nashville    TN
# 15     ZHVI    32162       The Villages    FL
# 16     ZHVI    11375           New York    NY
# 17     ZHVI    11235           New York    NY
# 18     ZHVI    78660       Pflugerville    TX
# ...

# %%
all_metro = list(real_estate['metro'].unique())

# %%
len(all_metro)
# Out:
# 832

# %%
# print(all_metro)

# %%
calendar = pd.read_csv('calendarorigional.csv')
calendar_df = calendar.loc[calendar['available']=='t']

# %%
metro_callist = list(calendar_df['metro_area'].unique())  # "Calendar List"

# %%
metro_callist
# Out:
# ['LA',
#  'oakland',
#  'san_diego',
#  'san_francisco',
#  'santa_cruz',
#  'seattle',
#  'portland']

# %%
# Change all the "San Francisco" in "Oakland" to "Oakland" 
index = 0
while index < len(real_estate):
    if real_estate.loc[index]['city'] == 'Oakland' and real_estate.loc[index]['metro'] == 'San Francisco':
        real_estate.at[index, 'metro'] = 'Oakland'
    index += 1

# %%
metro_list = ['Oakland', 'San Diego', 'San Francisco', 'Santa Cruz','Seattle','Portland']  # 'Los Angeles' excluded

# %%
# Test
main_metro = real_estate.loc[real_estate['metro'].str.contains("Santa Cruz")==True]
main_metro
# Out:
#        type  zipcode           city state                   metro      county  \
# 397    ZHVI    95076    Watsonville    CA  Santa Cruz-Watsonville  Santa Cruz
# 1039   ZHVI    95060     Santa Cruz    CA  Santa Cruz-Watsonville  Santa Cruz
# 1726   ZHVI    95062     Santa Cruz    CA  Santa Cruz-Watsonville  Santa Cruz
# 4081   ZHVI    95003          Aptos    CA  Santa Cruz-Watsonville  Santa Cruz
# 7192   ZHVI    95066  Scotts Valley    CA  Santa Cruz-Watsonville  Santa Cruz
# 7214   ZHVI    95010       Capitola    CA  Santa Cruz-Watsonville  Santa Cruz
# 8036   ZHVI    95073         Soquel    CA  Santa Cruz-Watsonville  Santa Cruz
# 8164   ZHVI    95006  Boulder Creek    CA  Santa Cruz-Watsonville  Santa Cruz
# 8940   ZHVI    95018         Felton    CA  Santa Cruz-Watsonville  Santa Cruz
# 9661   ZHVI    95065     Santa Cruz    CA  Santa Cruz-Watsonville  Santa Cruz
# 9827   ZHVI    95019        Freedom    CA  Santa Cruz-Watsonville  Santa Cruz
# ...

# %%
main_metro = real_estate.loc[real_estate['metro'].str.contains("Los Angeles")==True]
main_metro
# Out:
#        type  zipcode                   city state  \
# 19     ZHVI    90250              Hawthorne    CA
# 36     ZHVI    90046            Los Angeles    CA
# 86     ZHVI    90034            Los Angeles    CA
# 96     ZHVI    90044            Los Angeles    CA
# 99     ZHVI    90805             Long Beach    CA
# 100    ZHVI    90650                Norwalk    CA
# 102    ZHVI    92683            Westminster    CA
# 109    ZHVI    90026            Los Angeles    CA
# 143    ZHVI    90066            Los Angeles    CA
# 159    ZHVI    92677          Laguna Niguel    CA
# 169    ZHVI    92804                Anaheim    CA
# 188    ZHVI    90019            Los Angeles    CA
# 202    ZHVI    90280             South Gate    CA
# 220    ZHVI    90201                   Bell    CA
# 229    ZHVI    90004            Los Angeles    CA
# 234    ZHVI    90706             Bellflower    CA
# 243    ZHVI    91342            Los Angeles    CA
# 265    ZHVI    92627             Costa Mesa    CA
# ...

# %%
for element in metro_list:
    main_metro = main_metro.append(real_estate[real_estate['metro'].str.contains(element)==True])

# %%
main_metro
# Out:
#        type  zipcode              city state                           metro  \
# 19     ZHVI    90250         Hawthorne    CA  Los Angeles-Long Beach-Anaheim
# 36     ZHVI    90046       Los Angeles    CA  Los Angeles-Long Beach-Anaheim
# 86     ZHVI    90034       Los Angeles    CA  Los Angeles-Long Beach-Anaheim
# 96     ZHVI    90044       Los Angeles    CA  Los Angeles-Long Beach-Anaheim
# 99     ZHVI    90805        Long Beach    CA  Los Angeles-Long Beach-Anaheim
# 100    ZHVI    90650           Norwalk    CA  Los Angeles-Long Beach-Anaheim
# 102    ZHVI    92683       Westminster    CA  Los Angeles-Long Beach-Anaheim
# 109    ZHVI    90026       Los Angeles    CA  Los Angeles-Long Beach-Anaheim
# 143    ZHVI    90066       Los Angeles    CA  Los Angeles-Long Beach-Anaheim
# 159    ZHVI    92677     Laguna Niguel    CA  Los Angeles-Long Beach-Anaheim
# 169    ZHVI    92804           Anaheim    CA  Los Angeles-Long Beach-Anaheim
# ...

# %%
# A subset containing the seven metro in calendar dataset.
main_metro.to_csv('main_metro.csv', sep='\t')
